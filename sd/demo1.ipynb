# %%
import model_loader
import pipeline
from PIL import Image
from transformers import CLIPTokenizer
import torch

# %%
DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "gpu"

print(f"Device using: {DEVICE}")
# Out:
# Device using: cpu

# %%
tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
#       2 model_file = "../data/v1-5-pruned-emaonly.ckpt"
# ----> 3 models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)
#
# File t:\Tyb\Python\Machine Learning\PyTorch\Stable Diffusion Model\sd\model_loader.py:18, in preload_models_from_standard_weights(ckpt_path, device)
#      15 decoder.load_state_dict(state_dict['decoder'], strict=True)
#      17 diffusion = Diffusion().to(device)
# ---> 18 diffusion.load_state_dict(state_dict['diffusion'], strict=False)
#      20 clip = CLIP().to(device)
#      21 clip.load_state_dict(state_dict['clip'], strict=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:2189, in Module.load_state_dict(self, state_dict, strict, assign)
#    2184         error_msgs.insert(
#    2185             0, 'Missing key(s) in state_dict: {}. '.format(
#    2186                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2188 if len(error_msgs) > 0:
# -> 2189     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Diffusion:
# 	size mismatch for unet.encoders.1.1.attention_1.in_proj.weight: copying a param with shape torch.Size([960, 320]) from checkpoint, the shape in current model is torch.Size([120, 40]).
# 	size mismatch for unet.encoders.1.1.attention_1.out_proj.weight: copying a param with shape torch.Size([320, 320]) from checkpoint, the shape in current model is torch.Size([40, 40]).
# 	size mismatch for unet.encoders.1.1.attention_1.out_proj.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([40]).
# 	size mismatch for unet.encoders.1.1.attention_2.k_proj.weight: copying a param with shape torch.Size([320, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.encoders.1.1.attention_2.v_proj.weight: copying a param with shape torch.Size([320, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.encoders.1.1.linear_geglu_2.weight: copying a param with shape torch.Size([320, 1280]) from checkpoint, the shape in current model is torch.Size([320, 2560]).
# 	size mismatch for unet.encoders.2.1.attention_1.in_proj.weight: copying a param with shape torch.Size([960, 320]) from checkpoint, the shape in current model is torch.Size([120, 40]).
# 	size mismatch for unet.encoders.2.1.attention_1.out_proj.weight: copying a param with shape torch.Size([320, 320]) from checkpoint, the shape in current model is torch.Size([40, 40]).
# 	size mismatch for unet.encoders.2.1.attention_1.out_proj.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([40]).
# 	size mismatch for unet.encoders.2.1.attention_2.k_proj.weight: copying a param with shape torch.Size([320, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.encoders.2.1.attention_2.v_proj.weight: copying a param with shape torch.Size([320, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.encoders.2.1.linear_geglu_2.weight: copying a param with shape torch.Size([320, 1280]) from checkpoint, the shape in current model is torch.Size([320, 2560]).
# 	size mismatch for unet.encoders.4.1.attention_1.in_proj.weight: copying a param with shape torch.Size([1920, 640]) from checkpoint, the shape in current model is torch.Size([240, 80]).
# 	size mismatch for unet.encoders.4.1.attention_1.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([80, 80]).
# 	size mismatch for unet.encoders.4.1.attention_1.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for unet.encoders.4.1.attention_2.k_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.encoders.4.1.attention_2.v_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.encoders.4.1.linear_geglu_2.weight: copying a param with shape torch.Size([640, 2560]) from checkpoint, the shape in current model is torch.Size([640, 5120]).
# 	size mismatch for unet.encoders.5.1.attention_1.in_proj.weight: copying a param with shape torch.Size([1920, 640]) from checkpoint, the shape in current model is torch.Size([240, 80]).
# 	size mismatch for unet.encoders.5.1.attention_1.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([80, 80]).
# 	size mismatch for unet.encoders.5.1.attention_1.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for unet.encoders.5.1.attention_2.k_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.encoders.5.1.attention_2.v_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.encoders.5.1.linear_geglu_2.weight: copying a param with shape torch.Size([640, 2560]) from checkpoint, the shape in current model is torch.Size([640, 5120]).
# 	size mismatch for unet.encoders.7.1.attention_1.in_proj.weight: copying a param with shape torch.Size([3840, 1280]) from checkpoint, the shape in current model is torch.Size([480, 160]).
# 	size mismatch for unet.encoders.7.1.attention_1.out_proj.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([160, 160]).
# 	size mismatch for unet.encoders.7.1.attention_1.out_proj.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([160]).
# 	size mismatch for unet.encoders.7.1.attention_2.k_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([1280, 788]).
# 	size mismatch for unet.encoders.7.1.attention_2.v_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([1280, 788]).
# 	size mismatch for unet.encoders.7.1.linear_geglu_2.weight: copying a param with shape torch.Size([1280, 5120]) from checkpoint, the shape in current model is torch.Size([1280, 10240]).
# 	size mismatch for unet.encoders.8.1.attention_1.in_proj.weight: copying a param with shape torch.Size([3840, 1280]) from checkpoint, the shape in current model is torch.Size([480, 160]).
# 	size mismatch for unet.encoders.8.1.attention_1.out_proj.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([160, 160]).
# 	size mismatch for unet.encoders.8.1.attention_1.out_proj.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([160]).
# 	size mismatch for unet.encoders.8.1.attention_2.k_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([1280, 788]).
# 	size mismatch for unet.encoders.8.1.attention_2.v_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([1280, 788]).
# 	size mismatch for unet.encoders.8.1.linear_geglu_2.weight: copying a param with shape torch.Size([1280, 5120]) from checkpoint, the shape in current model is torch.Size([1280, 10240]).
# 	size mismatch for unet.decoders.3.0.groupnorm_feature.weight: copying a param with shape torch.Size([2560]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.3.0.groupnorm_feature.bias: copying a param with shape torch.Size([2560]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.3.0.conv_feature.weight: copying a param with shape torch.Size([1280, 2560, 3, 3]) from checkpoint, the shape in current model is torch.Size([1280, 1280, 3, 3]).
# 	size mismatch for unet.decoders.4.0.groupnorm_feature.weight: copying a param with shape torch.Size([2560]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.4.0.groupnorm_feature.bias: copying a param with shape torch.Size([2560]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.4.0.conv_feature.weight: copying a param with shape torch.Size([1280, 2560, 3, 3]) from checkpoint, the shape in current model is torch.Size([640, 1280, 3, 3]).
# 	size mismatch for unet.decoders.4.0.conv_feature.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.4.0.linear_time.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([640, 1280]).
# 	size mismatch for unet.decoders.4.0.linear_time.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.4.0.groupnorm_merged.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.4.0.groupnorm_merged.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.4.0.conv_merged.weight: copying a param with shape torch.Size([1280, 1280, 3, 3]) from checkpoint, the shape in current model is torch.Size([640, 640, 3, 3]).
# 	size mismatch for unet.decoders.4.0.conv_merged.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.4.0.residual_layer.weight: copying a param with shape torch.Size([1280, 2560, 1, 1]) from checkpoint, the shape in current model is torch.Size([640, 1280, 1, 1]).
# 	size mismatch for unet.decoders.4.0.residual_layer.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.groupnorm_feature.weight: copying a param with shape torch.Size([1920]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.5.0.groupnorm_feature.bias: copying a param with shape torch.Size([1920]) from checkpoint, the shape in current model is torch.Size([1280]).
# 	size mismatch for unet.decoders.5.0.conv_feature.weight: copying a param with shape torch.Size([1280, 1920, 3, 3]) from checkpoint, the shape in current model is torch.Size([640, 1280, 3, 3]).
# 	size mismatch for unet.decoders.5.0.conv_feature.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.linear_time.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([640, 1280]).
# 	size mismatch for unet.decoders.5.0.linear_time.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.groupnorm_merged.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.groupnorm_merged.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.conv_merged.weight: copying a param with shape torch.Size([1280, 1280, 3, 3]) from checkpoint, the shape in current model is torch.Size([640, 640, 3, 3]).
# 	size mismatch for unet.decoders.5.0.conv_merged.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.0.residual_layer.weight: copying a param with shape torch.Size([1280, 1920, 1, 1]) from checkpoint, the shape in current model is torch.Size([640, 1280, 1, 1]).
# 	size mismatch for unet.decoders.5.0.residual_layer.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.groupnorm.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.groupnorm.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.conv_input.weight: copying a param with shape torch.Size([1280, 1280, 1, 1]) from checkpoint, the shape in current model is torch.Size([640, 640, 1, 1]).
# 	size mismatch for unet.decoders.5.1.conv_input.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.layernorm_1.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.layernorm_1.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.attention_1.in_proj.weight: copying a param with shape torch.Size([3840, 1280]) from checkpoint, the shape in current model is torch.Size([240, 80]).
# 	size mismatch for unet.decoders.5.1.attention_1.out_proj.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([80, 80]).
# 	size mismatch for unet.decoders.5.1.attention_1.out_proj.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for unet.decoders.5.1.layernorm_2.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.layernorm_2.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.attention_2.q_proj.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([640, 640]).
# 	size mismatch for unet.decoders.5.1.attention_2.k_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.decoders.5.1.attention_2.v_proj.weight: copying a param with shape torch.Size([1280, 768]) from checkpoint, the shape in current model is torch.Size([640, 788]).
# 	size mismatch for unet.decoders.5.1.attention_2.out_proj.weight: copying a param with shape torch.Size([1280, 1280]) from checkpoint, the shape in current model is torch.Size([640, 640]).
# 	size mismatch for unet.decoders.5.1.attention_2.out_proj.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.layernorm_3.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.layernorm_3.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.linear_geglu_1.weight: copying a param with shape torch.Size([10240, 1280]) from checkpoint, the shape in current model is torch.Size([5120, 640]).
# 	size mismatch for unet.decoders.5.1.linear_geglu_1.bias: copying a param with shape torch.Size([10240]) from checkpoint, the shape in current model is torch.Size([5120]).
# 	size mismatch for unet.decoders.5.1.linear_geglu_2.weight: copying a param with shape torch.Size([1280, 5120]) from checkpoint, the shape in current model is torch.Size([640, 5120]).
# 	size mismatch for unet.decoders.5.1.linear_geglu_2.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.5.1.conv_output.weight: copying a param with shape torch.Size([1280, 1280, 1, 1]) from checkpoint, the shape in current model is torch.Size([640, 640, 1, 1]).
# 	size mismatch for unet.decoders.5.1.conv_output.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.6.0.groupnorm_feature.weight: copying a param with shape torch.Size([1920]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.6.0.groupnorm_feature.bias: copying a param with shape torch.Size([1920]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.6.0.conv_feature.weight: copying a param with shape torch.Size([640, 1920, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 640, 3, 3]).
# 	size mismatch for unet.decoders.6.0.conv_feature.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.0.linear_time.weight: copying a param with shape torch.Size([640, 1280]) from checkpoint, the shape in current model is torch.Size([320, 1280]).
# 	size mismatch for unet.decoders.6.0.linear_time.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.0.groupnorm_merged.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.0.groupnorm_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.0.conv_merged.weight: copying a param with shape torch.Size([640, 640, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 320, 3, 3]).
# 	size mismatch for unet.decoders.6.0.conv_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.0.residual_layer.weight: copying a param with shape torch.Size([640, 1920, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 640, 1, 1]).
# 	size mismatch for unet.decoders.6.0.residual_layer.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.groupnorm.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.groupnorm.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.conv_input.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.6.1.conv_input.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.layernorm_1.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.layernorm_1.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.attention_1.in_proj.weight: copying a param with shape torch.Size([1920, 640]) from checkpoint, the shape in current model is torch.Size([120, 40]).
# 	size mismatch for unet.decoders.6.1.attention_1.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([40, 40]).
# 	size mismatch for unet.decoders.6.1.attention_1.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([40]).
# 	size mismatch for unet.decoders.6.1.layernorm_2.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.layernorm_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.attention_2.q_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.6.1.attention_2.k_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.6.1.attention_2.v_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.6.1.attention_2.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.6.1.attention_2.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.layernorm_3.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.layernorm_3.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.linear_geglu_1.weight: copying a param with shape torch.Size([5120, 640]) from checkpoint, the shape in current model is torch.Size([2560, 320]).
# 	size mismatch for unet.decoders.6.1.linear_geglu_1.bias: copying a param with shape torch.Size([5120]) from checkpoint, the shape in current model is torch.Size([2560]).
# 	size mismatch for unet.decoders.6.1.linear_geglu_2.weight: copying a param with shape torch.Size([640, 2560]) from checkpoint, the shape in current model is torch.Size([320, 2560]).
# 	size mismatch for unet.decoders.6.1.linear_geglu_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.6.1.conv_output.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.6.1.conv_output.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.groupnorm_feature.weight: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.7.0.groupnorm_feature.bias: copying a param with shape torch.Size([1280]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.7.0.conv_feature.weight: copying a param with shape torch.Size([640, 1280, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 640, 3, 3]).
# 	size mismatch for unet.decoders.7.0.conv_feature.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.linear_time.weight: copying a param with shape torch.Size([640, 1280]) from checkpoint, the shape in current model is torch.Size([320, 1280]).
# 	size mismatch for unet.decoders.7.0.linear_time.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.groupnorm_merged.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.groupnorm_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.conv_merged.weight: copying a param with shape torch.Size([640, 640, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 320, 3, 3]).
# 	size mismatch for unet.decoders.7.0.conv_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.0.residual_layer.weight: copying a param with shape torch.Size([640, 1280, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 640, 1, 1]).
# 	size mismatch for unet.decoders.7.0.residual_layer.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.groupnorm.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.groupnorm.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.conv_input.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.7.1.conv_input.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.layernorm_1.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.layernorm_1.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.attention_1.in_proj.weight: copying a param with shape torch.Size([1920, 640]) from checkpoint, the shape in current model is torch.Size([120, 40]).
# 	size mismatch for unet.decoders.7.1.attention_1.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([40, 40]).
# 	size mismatch for unet.decoders.7.1.attention_1.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([40]).
# 	size mismatch for unet.decoders.7.1.layernorm_2.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.layernorm_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.attention_2.q_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.7.1.attention_2.k_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.7.1.attention_2.v_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.7.1.attention_2.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.7.1.attention_2.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.layernorm_3.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.layernorm_3.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.linear_geglu_1.weight: copying a param with shape torch.Size([5120, 640]) from checkpoint, the shape in current model is torch.Size([2560, 320]).
# 	size mismatch for unet.decoders.7.1.linear_geglu_1.bias: copying a param with shape torch.Size([5120]) from checkpoint, the shape in current model is torch.Size([2560]).
# 	size mismatch for unet.decoders.7.1.linear_geglu_2.weight: copying a param with shape torch.Size([640, 2560]) from checkpoint, the shape in current model is torch.Size([320, 2560]).
# 	size mismatch for unet.decoders.7.1.linear_geglu_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.7.1.conv_output.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.7.1.conv_output.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.groupnorm_feature.weight: copying a param with shape torch.Size([960]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.8.0.groupnorm_feature.bias: copying a param with shape torch.Size([960]) from checkpoint, the shape in current model is torch.Size([640]).
# 	size mismatch for unet.decoders.8.0.conv_feature.weight: copying a param with shape torch.Size([640, 960, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 640, 3, 3]).
# 	size mismatch for unet.decoders.8.0.conv_feature.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.linear_time.weight: copying a param with shape torch.Size([640, 1280]) from checkpoint, the shape in current model is torch.Size([320, 1280]).
# 	size mismatch for unet.decoders.8.0.linear_time.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.groupnorm_merged.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.groupnorm_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.conv_merged.weight: copying a param with shape torch.Size([640, 640, 3, 3]) from checkpoint, the shape in current model is torch.Size([320, 320, 3, 3]).
# 	size mismatch for unet.decoders.8.0.conv_merged.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.0.residual_layer.weight: copying a param with shape torch.Size([640, 960, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 640, 1, 1]).
# 	size mismatch for unet.decoders.8.0.residual_layer.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.groupnorm.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.groupnorm.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.conv_input.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.8.1.conv_input.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.layernorm_1.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.layernorm_1.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.attention_1.in_proj.weight: copying a param with shape torch.Size([1920, 640]) from checkpoint, the shape in current model is torch.Size([120, 40]).
# 	size mismatch for unet.decoders.8.1.attention_1.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([40, 40]).
# 	size mismatch for unet.decoders.8.1.attention_1.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([40]).
# 	size mismatch for unet.decoders.8.1.layernorm_2.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.layernorm_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.attention_2.q_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.8.1.attention_2.k_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.8.1.attention_2.v_proj.weight: copying a param with shape torch.Size([640, 768]) from checkpoint, the shape in current model is torch.Size([320, 788]).
# 	size mismatch for unet.decoders.8.1.attention_2.out_proj.weight: copying a param with shape torch.Size([640, 640]) from checkpoint, the shape in current model is torch.Size([320, 320]).
# 	size mismatch for unet.decoders.8.1.attention_2.out_proj.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.layernorm_3.weight: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.layernorm_3.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.linear_geglu_1.weight: copying a param with shape torch.Size([5120, 640]) from checkpoint, the shape in current model is torch.Size([2560, 320]).
# 	size mismatch for unet.decoders.8.1.linear_geglu_1.bias: copying a param with shape torch.Size([5120]) from checkpoint, the shape in current model is torch.Size([2560]).
# 	size mismatch for unet.decoders.8.1.linear_geglu_2.weight: copying a param with shape torch.Size([640, 2560]) from checkpoint, the shape in current model is torch.Size([320, 2560]).
# 	size mismatch for unet.decoders.8.1.linear_geglu_2.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).
# 	size mismatch for unet.decoders.8.1.conv_output.weight: copying a param with shape torch.Size([640, 640, 1, 1]) from checkpoint, the shape in current model is torch.Size([320, 320, 1, 1]).
# 	size mismatch for unet.decoders.8.1.conv_output.bias: copying a param with shape torch.Size([640]) from checkpoint, the shape in current model is torch.Size([320]).

# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.backends.mps.is_built() or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

## TEXT TO IMAGE

# prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

## IMAGE TO IMAGE

input_image = None
# Comment to disable image to image
image_path = "../images/dog.jpg"
# input_image = Image.open(image_path)
# Higher values means more noise will be added to the input image, so the result will further from the input image.
# Lower values means less noise is added to the input image, so output will be closer to the input image.
strength = 0.9

## SAMPLER

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
